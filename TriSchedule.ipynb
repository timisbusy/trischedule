# %%
import datetime

config = {
    "start_date": datetime.date.fromisoformat('2025-01-31'),
    "race_date": datetime.date.fromisoformat('2025-06-28'),
    "race_details": {
        "swim_distance": 1.5, # in km
        "bike_distance": 40, # in km
        "run_distance": 10 # in km
    },
    "current_fitness": 50, # 0-100
    "max_weekly_training": 10, # hours per week
    "max_block_weeks": 4 # maximum weeks per block
}

print(config)
# Out:
# {'start_date': datetime.date(2025, 1, 31), 'race_date': datetime.date(2025, 6, 28), 'race_details': {'swim_distance': 1.5, 'bike_distance': 40, 'run_distance': 10}, 'current_fitness': 50, 'max_weekly_training': 10, 'max_block_weeks': 4}

# %%
import pyomo.environ as pyo

def create_linear_periodization_plan(config):
    #TODO: validate incoming config (start date should be before race date, fitness should be in range, etc)

    
    available_weeks = []
    date_counter = config["start_date"] - datetime.timedelta(days=config["start_date"].weekday()) # weeks always start on monday
    while date_counter < config["race_date"]:
        next_week = date_counter + datetime.timedelta(days=7)
        available_weeks.append({ "start_date": date_counter, "end_date": next_week }) # note: next week is the first day of the next week
        date_counter = next_week

    weeks_periodized = assign_strategy_to_weeks(available_weeks,config)
    return weeks_periodized

def assign_strategy_to_weeks(available_weeks, config):
    #TODO: validate weeks incoming
    number_of_weeks = len(available_weeks)
    max_block_weeks = config["max_block_weeks"]

    print("number of weeks: ", number_of_weeks)

    available_week_types = {
        0: "rest",
        1: "peak",
        2: "base",
        3: "build"
    }

    #init pyomo model

    model = pyo.ConcreteModel()
    model.Weeks = pyo.RangeSet(0, number_of_weeks-1)
    
    model.AssignedValues = pyo.Var(model.Weeks, domain=pyo.NonNegativeIntegers, bounds=(0, 3))
    model.StartBlockWeeks = pyo.Var(model.Weeks, domain=pyo.Boolean)

    # maximize base periods and build periods
    model.obj = pyo.Objective(expr=sum(model.AssignedValues[n] for n in model.Weeks) - sum(model.StartBlockWeeks[n] for n in model.Weeks), sense=pyo.maximize)

    # constraints

    # last two weeks must not be assigned to base or build
    def peak_period_constraint_rule(m, week):
        if week > number_of_weeks - 3:
            return m.AssignedValues[week]  <= 1
        else:
            return pyo.Constraint.Skip
        
    model.peak_period_constraint = pyo.Constraint(model.Weeks, rule=peak_period_constraint_rule)

    # must have 12 base weeks before build

    def min_base_week_constraint_rule(m,week):   
        if week <= 12 :
            return m.AssignedValues[week] <= 2 
        else:
            return pyo.Constraint.Skip

    model.rest_week_constraint = pyo.Constraint(model.Weeks, rule=min_base_week_constraint_rule)

    # must start a block every time assigned[n] != assigned[n-1] - TODO: how to adjust this so it catches downward shifts as well?

    def start_block_on_transition_rule(m,week):
        if week == 0:
            return m.StartBlockWeeks[week] >= 1
        else:
            return m.AssignedValues[week] - m.AssignedValues[week - 1] - m.StartBlockWeeks[week] <= 0
            
    model.start_block_on_transition = pyo.Constraint(model.Weeks, rule=start_block_on_transition_rule)

    # must start a transition block at least every {max_block_weeks} weeks

    def start_block_periodically_rule(m,week):
        if week > max_block_weeks:
            week_window = range(week - max_block_weeks, week)
            return sum(m.StartBlockWeeks[n] for n in week_window) >= 1
        else:
            return pyo.Constraint.Skip

    model.start_block_periodically = pyo.Constraint(model.Weeks, rule=start_block_periodically_rule)
    
    # must not start a transition block more than {max_block_weeks - 1} weeks

    def start_block_periodically_rule_2(m,week):
        if week > max_block_weeks:
            week_window = range(week - (max_block_weeks - 1), week)
            return sum(m.StartBlockWeeks[n] for n in week_window) <= 1
        else:
            return pyo.Constraint.Skip
            

    model.start_block_periodically_2 = pyo.Constraint(model.Weeks, rule=start_block_periodically_rule_2)

    # solve
    
    solver = pyo.SolverFactory('glpk')
    solver.options['tmlim'] = 5
    results = solver.solve(model)
    

    # print results
    # print(results)
    model.pprint()


    # add strategy and if it is the start of a block to each week
    for idx, week in enumerate(available_weeks):
        week["strategy"] = available_week_types[model.AssignedValues[idx].value]
        week["start_block"] = model.StartBlockWeeks[idx].value == 1

    return available_weeks
    
    

week_plan = create_linear_periodization_plan(config)
print(week_plan)

for week in week_plan:
    print(week["start_date"], week["strategy"], week["start_block"])
# Out:
# number of weeks:  22
# 1 RangeSet Declarations
#     Weeks : Dimen=1, Size=22, Bounds=(0, 21)
#         Key  : Finite : Members
#         None :   True :  [0:21]
#
# 2 Var Declarations
#     AssignedValues : Size=22, Index=Weeks
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#           1 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#           2 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#           3 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#           4 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#           5 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#           6 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#           7 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#           8 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#           9 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#          10 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#          11 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#          12 :     0 :   2.0 :     3 : False : False : NonNegativeIntegers
#          13 :     0 :   3.0 :     3 : False : False : NonNegativeIntegers
#          14 :     0 :   3.0 :     3 : False : False : NonNegativeIntegers
#          15 :     0 :   3.0 :     3 : False : False : NonNegativeIntegers
#          16 :     0 :   3.0 :     3 : False : False : NonNegativeIntegers
#          17 :     0 :   3.0 :     3 : False : False : NonNegativeIntegers
#          18 :     0 :   3.0 :     3 : False : False : NonNegativeIntegers
#          19 :     0 :   3.0 :     3 : False : False : NonNegativeIntegers
#          20 :     0 :   1.0 :     3 : False : False : NonNegativeIntegers
#          21 :     0 :   1.0 :     3 : False : False : NonNegativeIntegers
#     StartBlockWeeks : Size=22, Index=Weeks
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :   1.0 :     1 : False : False : Boolean
#           1 :     0 :   0.0 :     1 : False : False : Boolean
#           2 :     0 :   0.0 :     1 : False : False : Boolean
#           3 :     0 :   0.0 :     1 : False : False : Boolean
#           4 :     0 :   1.0 :     1 : False : False : Boolean
#           5 :     0 :   0.0 :     1 : False : False : Boolean
#           6 :     0 :   0.0 :     1 : False : False : Boolean
#           7 :     0 :   1.0 :     1 : False : False : Boolean
#           8 :     0 :   0.0 :     1 : False : False : Boolean
#           9 :     0 :   0.0 :     1 : False : False : Boolean
#          10 :     0 :   1.0 :     1 : False : False : Boolean
#          11 :     0 :   0.0 :     1 : False : False : Boolean
#          12 :     0 :   0.0 :     1 : False : False : Boolean
#          13 :     0 :   1.0 :     1 : False : False : Boolean
#          14 :     0 :   0.0 :     1 : False : False : Boolean
#          15 :     0 :   0.0 :     1 : False : False : Boolean
#          16 :     0 :   0.0 :     1 : False : False : Boolean
#          17 :     0 :   1.0 :     1 : False : False : Boolean
#          18 :     0 :   0.0 :     1 : False : False : Boolean
#          19 :     0 :   0.0 :     1 : False : False : Boolean
#          20 :     0 :   0.0 :     1 : False : False : Boolean
#          21 :     0 :   0.0 :     1 : False : False : Boolean
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : AssignedValues[0] + AssignedValues[1] + AssignedValues[2] + AssignedValues[3] + AssignedValues[4] + AssignedValues[5] + AssignedValues[6] + AssignedValues[7] + AssignedValues[8] + AssignedValues[9] + AssignedValues[10] + AssignedValues[11] + AssignedValues[12] + AssignedValues[13] + AssignedValues[14] + AssignedValues[15] + AssignedValues[16] + AssignedValues[17] + AssignedValues[18] + AssignedValues[19] + AssignedValues[20] + AssignedValues[21] - (StartBlockWeeks[0] + StartBlockWeeks[1] + StartBlockWeeks[2] + StartBlockWeeks[3] + StartBlockWeeks[4] + StartBlockWeeks[5] + StartBlockWeeks[6] + StartBlockWeeks[7] + StartBlockWeeks[8] + StartBlockWeeks[9] + StartBlockWeeks[10] + StartBlockWeeks[11] + StartBlockWeeks[12] + StartBlockWeeks[13] + StartBlockWeeks[14] + StartBlockWeeks[15] + StartBlockWeeks[16] + StartBlockWeeks[17] + StartBlockWeeks[18] + StartBlockWeeks[19] + StartBlockWeeks[20] + StartBlockWeeks[21])
#
# 5 Constraint Declarations
#     peak_period_constraint : Size=2, Index=Weeks, Active=True
#         Key : Lower : Body               : Upper : Active
#          20 :  -Inf : AssignedValues[20] :   1.0 :   True
#          21 :  -Inf : AssignedValues[21] :   1.0 :   True
#     rest_week_constraint : Size=13, Index=Weeks, Active=True
#         Key : Lower : Body               : Upper : Active
#           0 :  -Inf :  AssignedValues[0] :   2.0 :   True
#           1 :  -Inf :  AssignedValues[1] :   2.0 :   True
#           2 :  -Inf :  AssignedValues[2] :   2.0 :   True
#           3 :  -Inf :  AssignedValues[3] :   2.0 :   True
#           4 :  -Inf :  AssignedValues[4] :   2.0 :   True
#           5 :  -Inf :  AssignedValues[5] :   2.0 :   True
#           6 :  -Inf :  AssignedValues[6] :   2.0 :   True
#           7 :  -Inf :  AssignedValues[7] :   2.0 :   True
#           8 :  -Inf :  AssignedValues[8] :   2.0 :   True
#           9 :  -Inf :  AssignedValues[9] :   2.0 :   True
#          10 :  -Inf : AssignedValues[10] :   2.0 :   True
#          11 :  -Inf : AssignedValues[11] :   2.0 :   True
#          12 :  -Inf : AssignedValues[12] :   2.0 :   True
#     start_block_on_transition : Size=22, Index=Weeks, Active=True
#         Key : Lower : Body                                                          : Upper : Active
#           0 :   1.0 :                                            StartBlockWeeks[0] :  +Inf :   True
#           1 :  -Inf :    AssignedValues[1] - AssignedValues[0] - StartBlockWeeks[1] :   0.0 :   True
#           2 :  -Inf :    AssignedValues[2] - AssignedValues[1] - StartBlockWeeks[2] :   0.0 :   True
#           3 :  -Inf :    AssignedValues[3] - AssignedValues[2] - StartBlockWeeks[3] :   0.0 :   True
#           4 :  -Inf :    AssignedValues[4] - AssignedValues[3] - StartBlockWeeks[4] :   0.0 :   True
#           5 :  -Inf :    AssignedValues[5] - AssignedValues[4] - StartBlockWeeks[5] :   0.0 :   True
#           6 :  -Inf :    AssignedValues[6] - AssignedValues[5] - StartBlockWeeks[6] :   0.0 :   True
#           7 :  -Inf :    AssignedValues[7] - AssignedValues[6] - StartBlockWeeks[7] :   0.0 :   True
#           8 :  -Inf :    AssignedValues[8] - AssignedValues[7] - StartBlockWeeks[8] :   0.0 :   True
#           9 :  -Inf :    AssignedValues[9] - AssignedValues[8] - StartBlockWeeks[9] :   0.0 :   True
#          10 :  -Inf :  AssignedValues[10] - AssignedValues[9] - StartBlockWeeks[10] :   0.0 :   True
#          11 :  -Inf : AssignedValues[11] - AssignedValues[10] - StartBlockWeeks[11] :   0.0 :   True
#          12 :  -Inf : AssignedValues[12] - AssignedValues[11] - StartBlockWeeks[12] :   0.0 :   True
#          13 :  -Inf : AssignedValues[13] - AssignedValues[12] - StartBlockWeeks[13] :   0.0 :   True
#          14 :  -Inf : AssignedValues[14] - AssignedValues[13] - StartBlockWeeks[14] :   0.0 :   True
#          15 :  -Inf : AssignedValues[15] - AssignedValues[14] - StartBlockWeeks[15] :   0.0 :   True
#          16 :  -Inf : AssignedValues[16] - AssignedValues[15] - StartBlockWeeks[16] :   0.0 :   True
#          17 :  -Inf : AssignedValues[17] - AssignedValues[16] - StartBlockWeeks[17] :   0.0 :   True
#          18 :  -Inf : AssignedValues[18] - AssignedValues[17] - StartBlockWeeks[18] :   0.0 :   True
#          19 :  -Inf : AssignedValues[19] - AssignedValues[18] - StartBlockWeeks[19] :   0.0 :   True
#          20 :  -Inf : AssignedValues[20] - AssignedValues[19] - StartBlockWeeks[20] :   0.0 :   True
#          21 :  -Inf : AssignedValues[21] - AssignedValues[20] - StartBlockWeeks[21] :   0.0 :   True
#     start_block_periodically : Size=17, Index=Weeks, Active=True
#         Key : Lower : Body                                                                                  : Upper : Active
#           5 :   1.0 :     StartBlockWeeks[1] + StartBlockWeeks[2] + StartBlockWeeks[3] + StartBlockWeeks[4] :  +Inf :   True
#           6 :   1.0 :     StartBlockWeeks[2] + StartBlockWeeks[3] + StartBlockWeeks[4] + StartBlockWeeks[5] :  +Inf :   True
#           7 :   1.0 :     StartBlockWeeks[3] + StartBlockWeeks[4] + StartBlockWeeks[5] + StartBlockWeeks[6] :  +Inf :   True
#           8 :   1.0 :     StartBlockWeeks[4] + StartBlockWeeks[5] + StartBlockWeeks[6] + StartBlockWeeks[7] :  +Inf :   True
#           9 :   1.0 :     StartBlockWeeks[5] + StartBlockWeeks[6] + StartBlockWeeks[7] + StartBlockWeeks[8] :  +Inf :   True
#          10 :   1.0 :     StartBlockWeeks[6] + StartBlockWeeks[7] + StartBlockWeeks[8] + StartBlockWeeks[9] :  +Inf :   True
#          11 :   1.0 :    StartBlockWeeks[7] + StartBlockWeeks[8] + StartBlockWeeks[9] + StartBlockWeeks[10] :  +Inf :   True
#          12 :   1.0 :   StartBlockWeeks[8] + StartBlockWeeks[9] + StartBlockWeeks[10] + StartBlockWeeks[11] :  +Inf :   True
#          13 :   1.0 :  StartBlockWeeks[9] + StartBlockWeeks[10] + StartBlockWeeks[11] + StartBlockWeeks[12] :  +Inf :   True
#          14 :   1.0 : StartBlockWeeks[10] + StartBlockWeeks[11] + StartBlockWeeks[12] + StartBlockWeeks[13] :  +Inf :   True
#          15 :   1.0 : StartBlockWeeks[11] + StartBlockWeeks[12] + StartBlockWeeks[13] + StartBlockWeeks[14] :  +Inf :   True
#          16 :   1.0 : StartBlockWeeks[12] + StartBlockWeeks[13] + StartBlockWeeks[14] + StartBlockWeeks[15] :  +Inf :   True
#          17 :   1.0 : StartBlockWeeks[13] + StartBlockWeeks[14] + StartBlockWeeks[15] + StartBlockWeeks[16] :  +Inf :   True
#          18 :   1.0 : StartBlockWeeks[14] + StartBlockWeeks[15] + StartBlockWeeks[16] + StartBlockWeeks[17] :  +Inf :   True
#          19 :   1.0 : StartBlockWeeks[15] + StartBlockWeeks[16] + StartBlockWeeks[17] + StartBlockWeeks[18] :  +Inf :   True
#          20 :   1.0 : StartBlockWeeks[16] + StartBlockWeeks[17] + StartBlockWeeks[18] + StartBlockWeeks[19] :  +Inf :   True
#          21 :   1.0 : StartBlockWeeks[17] + StartBlockWeeks[18] + StartBlockWeeks[19] + StartBlockWeeks[20] :  +Inf :   True
#     start_block_periodically_2 : Size=17, Index=Weeks, Active=True
#         Key : Lower : Body                                                            : Upper : Active
#           5 :  -Inf :    StartBlockWeeks[2] + StartBlockWeeks[3] + StartBlockWeeks[4] :   1.0 :   True
#           6 :  -Inf :    StartBlockWeeks[3] + StartBlockWeeks[4] + StartBlockWeeks[5] :   1.0 :   True
#           7 :  -Inf :    StartBlockWeeks[4] + StartBlockWeeks[5] + StartBlockWeeks[6] :   1.0 :   True
#           8 :  -Inf :    StartBlockWeeks[5] + StartBlockWeeks[6] + StartBlockWeeks[7] :   1.0 :   True
#           9 :  -Inf :    StartBlockWeeks[6] + StartBlockWeeks[7] + StartBlockWeeks[8] :   1.0 :   True
#          10 :  -Inf :    StartBlockWeeks[7] + StartBlockWeeks[8] + StartBlockWeeks[9] :   1.0 :   True
#          11 :  -Inf :   StartBlockWeeks[8] + StartBlockWeeks[9] + StartBlockWeeks[10] :   1.0 :   True
#          12 :  -Inf :  StartBlockWeeks[9] + StartBlockWeeks[10] + StartBlockWeeks[11] :   1.0 :   True
#          13 :  -Inf : StartBlockWeeks[10] + StartBlockWeeks[11] + StartBlockWeeks[12] :   1.0 :   True
#          14 :  -Inf : StartBlockWeeks[11] + StartBlockWeeks[12] + StartBlockWeeks[13] :   1.0 :   True
#          15 :  -Inf : StartBlockWeeks[12] + StartBlockWeeks[13] + StartBlockWeeks[14] :   1.0 :   True
#          16 :  -Inf : StartBlockWeeks[13] + StartBlockWeeks[14] + StartBlockWeeks[15] :   1.0 :   True
#          17 :  -Inf : StartBlockWeeks[14] + StartBlockWeeks[15] + StartBlockWeeks[16] :   1.0 :   True
#          18 :  -Inf : StartBlockWeeks[15] + StartBlockWeeks[16] + StartBlockWeeks[17] :   1.0 :   True
#          19 :  -Inf : StartBlockWeeks[16] + StartBlockWeeks[17] + StartBlockWeeks[18] :   1.0 :   True
#          20 :  -Inf : StartBlockWeeks[17] + StartBlockWeeks[18] + StartBlockWeeks[19] :   1.0 :   True
#          21 :  -Inf : StartBlockWeeks[18] + StartBlockWeeks[19] + StartBlockWeeks[20] :   1.0 :   True
#
# 9 Declarations: Weeks AssignedValues StartBlockWeeks obj peak_period_constraint rest_week_constraint start_block_on_transition start_block_periodically start_block_periodically_2
# [{'start_date': datetime.date(2025, 1, 27), 'end_date': datetime.date(2025, 2, 3), 'strategy': 'base', 'start_block': True}, {'start_date': datetime.date(2025, 2, 3), 'end_date': datetime.date(2025, 2, 10), 'strategy': 'base', 'start_block': False}, {'start_date': datetime.date(2025, 2, 10), 'end_date': datetime.date(2025, 2, 17), 'strategy': 'base', 'start_block': False}, {'start_date': datetime.date(2025, 2, 17), 'end_date': datetime.date(2025, 2, 24), 'strategy': 'base', 'start_block': False}, {'start_date': datetime.date(2025, 2, 24), 'end_date': datetime.date(2025, 3, 3), 'strategy': 'base', 'start_block': True}, {'start_date': datetime.date(2025, 3, 3), 'end_date': datetime.date(2025, 3, 10), 'strategy': 'base', 'start_block': False}, {'start_date': datetime.date(2025, 3, 10), 'end_date': datetime.date(2025, 3, 17), 'strategy': 'base', 'start_block': False}, {'start_date': datetime.date(2025, 3, 17), 'end_date': datetime.date(2025, 3, 24), 'strategy': 'base', 'start_block': True}, {'start_date': datetime.date(2025, 3, 24), 'end_date': datetime.date(2025, 3, 31), 'strategy': 'base', 'start_block': False}, {'start_date': datetime.date(2025, 3, 31), 'end_date': datetime.date(2025, 4, 7), 'strategy': 'base', 'start_block': False}, {'start_date': datetime.date(2025, 4, 7), 'end_date': datetime.date(2025, 4, 14), 'strategy': 'base', 'start_block': True}, {'start_date': datetime.date(2025, 4, 14), 'end_date': datetime.date(2025, 4, 21), 'strategy': 'base', 'start_block': False}, {'start_date': datetime.date(2025, 4, 21), 'end_date': datetime.date(2025, 4, 28), 'strategy': 'base', 'start_block': False}, {'start_date': datetime.date(2025, 4, 28), 'end_date': datetime.date(2025, 5, 5), 'strategy': 'build', 'start_block': True}, {'start_date': datetime.date(2025, 5, 5), 'end_date': datetime.date(2025, 5, 12), 'strategy': 'build', 'start_block': False}, {'start_date': datetime.date(2025, 5, 12), 'end_date': datetime.date(2025, 5, 19), 'strategy': 'build', 'start_block': False}, {'start_date': datetime.date(2025, 5, 19), 'end_date': datetime.date(2025, 5, 26), 'strategy': 'build', 'start_block': False}, {'start_date': datetime.date(2025, 5, 26), 'end_date': datetime.date(2025, 6, 2), 'strategy': 'build', 'start_block': True}, {'start_date': datetime.date(2025, 6, 2), 'end_date': datetime.date(2025, 6, 9), 'strategy': 'build', 'start_block': False}, {'start_date': datetime.date(2025, 6, 9), 'end_date': datetime.date(2025, 6, 16), 'strategy': 'build', 'start_block': False}, {'start_date': datetime.date(2025, 6, 16), 'end_date': datetime.date(2025, 6, 23), 'strategy': 'peak', 'start_block': False}, {'start_date': datetime.date(2025, 6, 23), 'end_date': datetime.date(2025, 6, 30), 'strategy': 'peak', 'start_block': False}]
# 2025-01-27 base True
# 2025-02-03 base False
# 2025-02-10 base False
# 2025-02-17 base False
# 2025-02-24 base True
# 2025-03-03 base False
# 2025-03-10 base False
# 2025-03-17 base True
# 2025-03-24 base False
# 2025-03-31 base False
# 2025-04-07 base True
# 2025-04-14 base False
# 2025-04-21 base False
# 2025-04-28 build True
# 2025-05-05 build False
# 2025-05-12 build False
# 2025-05-19 build False
# 2025-05-26 build True
# 2025-06-02 build False
# 2025-06-09 build False
# 2025-06-16 peak False
# 2025-06-23 peak False

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from lib.workout_planner import *



def print_to_csv(filename, week_plan):
    with open(filename, "wt") as file:
        writer = csv.writer(file)
        writer.writerow(["Plan for {} week starting {}".format(week_plan["strategy"],week_plan["start_date"])])
        writer.writerow(["date", "sport", "name", "intensity", "duration"])
        for day, day_workouts in enumerate(week_plan["workouts"]):
            for workout in day_workouts:
                writer.writerow([week_plan["start_date"] + datetime.timedelta(days=day), workout["sport"], workout["workout_name"], workout["intensity"], workout["duration"]])


                
for week_number, week in enumerate(week_plan):
    
    incoming_fatigue = { "bike": 30, "run": 30, "swim": 30 }
    incoming_fitness = { "bike": 50, "run": 50, "swim": 50 }

    if week_number > 0:
        incoming_fatigue = week_plan[week_number-1]["fatigue_outcome"]
        incoming_fitness = week_plan[week_number-1]["fitness_outcome"]


    is_last_week_of_block = False
    if week_number < len(week_plan) - 1:
        is_last_week_of_block = week_plan[week_number+1]["start_block"]
    
    week_with_workouts = add_workouts_to_week_plan(week, incoming_fatigue, incoming_fitness, is_last_week_of_block, 5)
    print(week_with_workouts)
    
    for idx, workout in enumerate(week_with_workouts["workouts"]):
        print(idx, workout)

    

    # write to a file
    print_to_csv("./test_workout_plan_week_{}.csv".format(week_number), week_with_workouts)
# Out:
# ['swim', 'recovery swim', '1', '15', '1', '.2', '']
# ['swim', 'aerobic intervals', '4', '40', '10', '2', '']
# ['swim', 'tempo intervals', '6', '30', '20', '3', '']
# ['swim', 'muscular force reps', '7', '30', '30', '3', '']
# ['swim', 'open water current intervals', '8', '20', '30', '3', '']
# ['swim', 'aerobic intervals with paddles', '4', '30', '15', '2.5', '']
# ['swim', 'fast form 25s', '3', '20', '10', '1', '']
# ['swim', 'toy sets', '3', '20', '10', '1', '']
# ['swim', 'long cruise intervals', '8', '40', '60', '4', 'base']
# ['swim', 'short cruise intervals', '8', '30', '40', '3', 'base']
# ['swim', 'threshold', '7', '20', '50', '3', 'base']
# ['swim', 'vo2 max intervals', '9', '20', '70', '4', 'base']
# ['swim', 'anaerobic capacity intervals', '10', '20', '75', '4.5', 'base']
# ['bike', 'recovery bike', '1', '30', '1', '.2', '']
# ['bike', 'aerobic threshold', '3', '70', '30', '2', '']
# ['bike', 'intensive endurance', '7', '90', '40', '3', '']
# ['bike', 'force reps', '8', '40', '60', '3', '']
# ['bike', 'hilly ride', '8', '60', '50', '4', '']
# ['bike', 'hill repeats', '9', '30', '50', '3.5', '']
# ['bike', 'spin ups', '3', '20', '10', '1', '']
# ['bike', 'isolated leg', '3', '25', '15', '1.5', '']
# ['bike', 'tempo intervals', '6', '100', '60', '4.5', 'base']
# ['bike', 'cruise intervals', '7', '50', '50', '4', 'base']
# ['bike', 'hill cruise intervals', '7', '50', '60', '4.5', 'base']
# ['bike', 'crisscross intervals', '8', '50', '60', '5', 'base']
# ['bike', 'threshold ride', '8', '40', '50', '5', 'base']
# ['bike', 'group ride', '9', '90', '70', '5.5', 'base']
# ['bike', 'vo2 max intervals', '9', '30', '50', '5', 'base']
# ['bike', 'pyramid intervals', '9', '30', '55', '5.5', 'base']
# ['bike', 'hill intervals', '9', '30', '65', '6', 'base']
# ['run', 'run recovery', '1', '15', '1', '.2', '']
# ['run', 'aerobic threshold', '3', '40', '30', '2', '']
# ['run', 'intensive endurance', '5', '50', '50', '4', '']
# ['run', 'force reps', '8', '30', '60', '3', '']
# ['run', 'hilly run', '8', '40', '50', '3', '']
# ['run', 'hill repeats', '8', '40', '60', '4', '']
# ['run', 'strides', '9', '20', '20', '2', '']
# ['run', 'pickups', '8', '50', '55', '4.5', '']
# ['run', 'tempo', '7', '30', '40', '3', 'base']
# ['run', 'cruise intervals', '7', '60', '55', '5', 'base']
# ['run', 'hill cruise intervals', '7', '60', '60', '5.5', 'base']
# ['run', 'crisscross intervals', '9', '30', '50', '4.5', 'base']
# ['run', 'group run', '9', '40', '60', '5', 'base']
# ['run', 'vo2 max intervals', '9', '30', '65', '5', 'base']
# ['run', 'hill intervals', '9', '40', '65', '6', 'base']
# {'swim': 35.0, 'bike': 15.0, 'run': 20.0}
# {'start_date': datetime.date(2025, 1, 27), 'end_date': datetime.date(2025, 2, 3), 'strategy': 'base', 'start_block': True, 'workouts': [[{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'fast form 25s', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}], [], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'hill repeats', 'intensity': 8.0, 'duration': 40.0, 'fatigue_increase': 60.0, 'fitness_increase': 4.0, 'week_blocks': ''}]], 'fitness_outcome': {'run': 55.5, 'bike': 54.0, 'swim': 59.5}, 'fatigue_outcome': {'swim': 35.0, 'bike': 15.0, 'run': 20.0}}
# 0 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 1 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 2 [{'sport': 'swim', 'workout_name': 'fast form 25s', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}]
# 3 []
# 4 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 5 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'hill repeats', 'intensity': 8.0, 'duration': 40.0, 'fatigue_increase': 60.0, 'fitness_increase': 4.0, 'week_blocks': ''}]
# {'swim': 35.0, 'bike': 50.0, 'run': 20.0}
# {'start_date': datetime.date(2025, 2, 3), 'end_date': datetime.date(2025, 2, 10), 'strategy': 'base', 'start_block': False, 'workouts': [[{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}], [], [{'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hilly ride', 'intensity': 8.0, 'duration': 60.0, 'fatigue_increase': 50.0, 'fitness_increase': 4.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]], 'fitness_outcome': {'run': 61.224999999999994, 'bike': 58.8, 'swim': 67.525}, 'fatigue_outcome': {'swim': 35.0, 'bike': 50.0, 'run': 20.0}}
# 0 [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 1 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}]
# 2 []
# 3 [{'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 4 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}]
# 5 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hilly ride', 'intensity': 8.0, 'duration': 60.0, 'fatigue_increase': 50.0, 'fitness_increase': 4.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]
# {'swim': 35.0, 'bike': 15.0, 'run': 20.0}
# {'start_date': datetime.date(2025, 2, 10), 'end_date': datetime.date(2025, 2, 17), 'strategy': 'base', 'start_block': False, 'workouts': [[{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [{'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]], 'fitness_outcome': {'run': 66.66375, 'bike': 63.35999999999999, 'swim': 72.64875}, 'fatigue_outcome': {'swim': 35.0, 'bike': 15.0, 'run': 20.0}}
# 0 [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 1 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 2 [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}]
# 3 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 4 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 5 [{'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]
# {'swim': 30.0, 'bike': 50.0, 'run': 0.0}
# {'start_date': datetime.date(2025, 2, 17), 'end_date': datetime.date(2025, 2, 24), 'strategy': 'base', 'start_block': False, 'workouts': [[{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}], [], [{'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [], [], [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]], 'fitness_outcome': {'run': 65.33056249999998, 'bike': 70.692, 'swim': 75.0163125}, 'fatigue_outcome': {'swim': 30.0, 'bike': 50.0, 'run': 0.0}}
# 0 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]
# 1 []
# 2 [{'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 3 []
# 4 []
# 5 [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]
# 6 [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]
# {'swim': 15.0, 'bike': 10.0, 'run': 70.0}
# {'start_date': datetime.date(2025, 2, 24), 'end_date': datetime.date(2025, 3, 3), 'strategy': 'base', 'start_block': True, 'workouts': [[{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}], [], [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'intensive endurance', 'intensity': 5.0, 'duration': 50.0, 'fatigue_increase': 50.0, 'fitness_increase': 4.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]], 'fitness_outcome': {'run': 74.56403437499998, 'bike': 72.6574, 'swim': 79.265496875}, 'fatigue_outcome': {'swim': 15.0, 'bike': 10.0, 'run': 70.0}}
# 0 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 1 [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}]
# 2 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}]
# 3 []
# 4 [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 5 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'intensive endurance', 'intensity': 5.0, 'duration': 50.0, 'fatigue_increase': 50.0, 'fitness_increase': 4.0, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]
# {'swim': 20.0, 'bike': 15.0, 'run': 20.0}
# {'start_date': datetime.date(2025, 3, 3), 'end_date': datetime.date(2025, 3, 10), 'strategy': 'base', 'start_block': False, 'workouts': [[{'sport': 'swim', 'workout_name': 'fast form 25s', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]], 'fitness_outcome': {'run': 79.33583265624998, 'bike': 76.52453, 'swim': 84.80222203125}, 'fatigue_outcome': {'swim': 20.0, 'bike': 15.0, 'run': 20.0}}
# 0 [{'sport': 'swim', 'workout_name': 'fast form 25s', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 1 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 2 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}]
# 3 [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 4 []
# 5 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]
# {'swim': 0.0, 'bike': 50.0, 'run': 20.0}
# {'start_date': datetime.date(2025, 3, 10), 'end_date': datetime.date(2025, 3, 17), 'strategy': 'base', 'start_block': False, 'workouts': [[{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [], [], [], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]], 'fitness_outcome': {'run': 77.36904102343748, 'bike': 83.1983035, 'swim': 86.56211092968749}, 'fatigue_outcome': {'swim': 0.0, 'bike': 50.0, 'run': 20.0}}
# 0 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]
# 1 [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 2 []
# 3 []
# 4 []
# 5 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 6 [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]
# {'swim': 35.0, 'bike': 0.0, 'run': 55.0}
# {'start_date': datetime.date(2025, 3, 17), 'end_date': datetime.date(2025, 3, 24), 'strategy': 'base', 'start_block': True, 'workouts': [[{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}], [], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]], 'fitness_outcome': {'run': 84.5005889722656, 'bike': 84.03838832499999, 'swim': 93.23400538320311}, 'fatigue_outcome': {'swim': 35.0, 'bike': 0.0, 'run': 55.0}}
# 0 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 1 [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 2 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}]
# 3 []
# 4 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 5 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]
# {'swim': 35.0, 'bike': 25.0, 'run': 20.0}
# {'start_date': datetime.date(2025, 3, 24), 'end_date': datetime.date(2025, 3, 31), 'strategy': 'base', 'start_block': False, 'workouts': [[{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]], 'fitness_outcome': {'run': 88.77555952365232, 'bike': 88.33646890874998, 'swim': 97.07230511404295}, 'fatigue_outcome': {'swim': 35.0, 'bike': 25.0, 'run': 20.0}}
# 0 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}]
# 1 [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 2 []
# 3 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}]
# 4 [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 5 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]
# {'swim': 30.0, 'bike': 50.0, 'run': 0.0}
# {'start_date': datetime.date(2025, 3, 31), 'end_date': datetime.date(2025, 4, 7), 'strategy': 'base', 'start_block': False, 'workouts': [[{'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [], [], [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'force reps', 'intensity': 8.0, 'duration': 30.0, 'fatigue_increase': 60.0, 'fitness_increase': 3.0, 'week_blocks': ''}]], 'fitness_outcome': {'run': 89.3367815474697, 'bike': 90.91964546331248, 'swim': 98.2186898583408}, 'fatigue_outcome': {'swim': 30.0, 'bike': 50.0, 'run': 0.0}}
# 0 [{'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 1 [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 2 []
# 3 []
# 4 [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 5 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'force reps', 'intensity': 8.0, 'duration': 30.0, 'fatigue_increase': 60.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# {'swim': 15.0, 'bike': 60.0, 'run': 20.0}
# {'start_date': datetime.date(2025, 4, 7), 'end_date': datetime.date(2025, 4, 14), 'strategy': 'base', 'start_block': True, 'workouts': [[{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]], 'fitness_outcome': {'run': 93.3699424700962, 'bike': 94.37366319014684, 'swim': 103.30775536542374}, 'fatigue_outcome': {'swim': 15.0, 'bike': 60.0, 'run': 20.0}}
# 0 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 1 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}]
# 2 [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 3 [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 4 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}]
# 5 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]
# {'swim': 20.0, 'bike': 25.0, 'run': 20.0}
# {'start_date': datetime.date(2025, 4, 14), 'end_date': datetime.date(2025, 4, 21), 'strategy': 'base', 'start_block': False, 'workouts': [[{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}], [{'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]], 'fitness_outcome': {'run': 97.20144534659138, 'bike': 98.15498003063949, 'swim': 106.64236759715256}, 'fatigue_outcome': {'swim': 20.0, 'bike': 25.0, 'run': 20.0}}
# 0 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}]
# 1 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 2 [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 3 [{'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}]
# 4 [{'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 5 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'pickups', 'intensity': 8.0, 'duration': 50.0, 'fatigue_increase': 55.0, 'fitness_increase': 4.5, 'week_blocks': ''}]
# {'swim': 30.0, 'bike': 50.0, 'run': 0.0}
# {'start_date': datetime.date(2025, 4, 21), 'end_date': datetime.date(2025, 4, 28), 'strategy': 'base', 'start_block': False, 'workouts': [[{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [], [], [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'force reps', 'intensity': 8.0, 'duration': 30.0, 'fatigue_increase': 60.0, 'fitness_increase': 3.0, 'week_blocks': ''}]], 'fitness_outcome': {'run': 97.34137307926181, 'bike': 100.24723102910751, 'swim': 107.31024921729492}, 'fatigue_outcome': {'swim': 30.0, 'bike': 50.0, 'run': 0.0}}
# 0 [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 1 []
# 2 []
# 3 [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 4 []
# 5 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill repeats', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 3.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'force reps', 'intensity': 8.0, 'duration': 30.0, 'fatigue_increase': 60.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# {'swim': 35.0, 'bike': 55.0, 'run': 20.0}
# {'start_date': datetime.date(2025, 4, 28), 'end_date': datetime.date(2025, 5, 5), 'strategy': 'build', 'start_block': True, 'workouts': [[{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [], [], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'pyramid intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 55.0, 'fitness_increase': 5.5, 'week_blocks': 'base'}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]], 'fitness_outcome': {'run': 102.47430442529871, 'bike': 106.73486947765213, 'swim': 112.44473675643017}, 'fatigue_outcome': {'swim': 35.0, 'bike': 55.0, 'run': 20.0}}
# 0 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 1 [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 2 []
# 3 []
# 4 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'pyramid intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 55.0, 'fitness_increase': 5.5, 'week_blocks': 'base'}]
# 5 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
# {'swim': 15.0, 'bike': 15.0, 'run': 20.0}
# ...
# {'swim': 0.0, 'bike': 55.0, 'run': 65.0}
# {'start_date': datetime.date(2025, 5, 19), 'end_date': datetime.date(2025, 5, 26), 'strategy': 'build', 'start_block': False, 'workouts': [[{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [], [], [{'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}], [], [{'sport': 'bike', 'workout_name': 'pyramid intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 55.0, 'fitness_increase': 5.5, 'week_blocks': 'base'}], [{'sport': 'swim', 'workout_name': 'anaerobic capacity intervals', 'intensity': 10.0, 'duration': 20.0, 'fatigue_increase': 75.0, 'fitness_increase': 4.5, 'week_blocks': 'base'}, {'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]], 'fitness_outcome': {'run': 114.28390675664046, 'bike': 121.58430871840199, 'swim': 123.8573061765443}, 'fatigue_outcome': {'swim': 0.0, 'bike': 55.0, 'run': 65.0}}
# 0 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 1 []
# 2 []
# 3 [{'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
# 4 []
# 5 [{'sport': 'bike', 'workout_name': 'pyramid intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 55.0, 'fitness_increase': 5.5, 'week_blocks': 'base'}]
# 6 [{'sport': 'swim', 'workout_name': 'anaerobic capacity intervals', 'intensity': 10.0, 'duration': 20.0, 'fatigue_increase': 75.0, 'fitness_increase': 4.5, 'week_blocks': 'base'}, {'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
# {'swim': 30.0, 'bike': 15.0, 'run': 20.0}
# {'start_date': datetime.date(2025, 5, 26), 'end_date': datetime.date(2025, 6, 2), 'strategy': 'build', 'start_block': True, 'workouts': [[], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]], 'fitness_outcome': {'run': 118.56971141880844, 'bike': 123.00509328248188, 'swim': 128.16444086771708}, 'fatigue_outcome': {'swim': 30.0, 'bike': 15.0, 'run': 20.0}}
# 0 []
# 1 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 2 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 3 [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 4 [{'sport': 'bike', 'workout_name': 'isolated leg', 'intensity': 3.0, 'duration': 25.0, 'fatigue_increase': 15.0, 'fitness_increase': 1.5, 'week_blocks': ''}]
# 5 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'strides', 'intensity': 9.0, 'duration': 20.0, 'fatigue_increase': 20.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
# {'swim': 35.0, 'bike': 0.0, 'run': 60.0}
# {'start_date': datetime.date(2025, 6, 2), 'end_date': datetime.date(2025, 6, 9), 'strategy': 'build', 'start_block': False, 'workouts': [[{'sport': 'bike', 'workout_name': 'pyramid intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 55.0, 'fitness_increase': 5.5, 'week_blocks': 'base'}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}], [{'sport': 'run', 'workout_name': 'hill cruise intervals', 'intensity': 7.0, 'duration': 60.0, 'fatigue_increase': 60.0, 'fitness_increase': 5.5, 'week_blocks': 'base'}], [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]], 'fitness_outcome': {'run': 124.14122584786801, 'bike': 128.35483861835777, 'swim': 131.7562188243312}, 'fatigue_outcome': {'swim': 35.0, 'bike': 0.0, 'run': 60.0}}
# 0 [{'sport': 'bike', 'workout_name': 'pyramid intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 55.0, 'fitness_increase': 5.5, 'week_blocks': 'base'}]
# 1 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}]
# 2 [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 3 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 4 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}]
# 5 [{'sport': 'run', 'workout_name': 'hill cruise intervals', 'intensity': 7.0, 'duration': 60.0, 'fatigue_increase': 60.0, 'fitness_increase': 5.5, 'week_blocks': 'base'}]
# 6 [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
# {'swim': 45.0, 'bike': 0.0, 'run': 65.0}
# {'start_date': datetime.date(2025, 6, 9), 'end_date': datetime.date(2025, 6, 16), 'strategy': 'build', 'start_block': False, 'workouts': [[{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}], [], [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}], [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]], 'fitness_outcome': {'run': 129.9341645554746, 'bike': 128.93709668743986, 'swim': 137.16840788311464}, 'fatigue_outcome': {'swim': 45.0, 'bike': 0.0, 'run': 65.0}}
# 0 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}, {'sport': 'bike', 'workout_name': 'spin ups', 'intensity': 3.0, 'duration': 20.0, 'fatigue_increase': 10.0, 'fitness_increase': 1.0, 'week_blocks': ''}]
# 1 [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}]
# 2 []
# 3 [{'sport': 'swim', 'workout_name': 'aerobic intervals with paddles', 'intensity': 4.0, 'duration': 30.0, 'fatigue_increase': 15.0, 'fitness_increase': 2.5, 'week_blocks': ''}]
# 4 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 5 [{'sport': 'swim', 'workout_name': 'aerobic intervals', 'intensity': 4.0, 'duration': 40.0, 'fatigue_increase': 10.0, 'fitness_increase': 2.0, 'week_blocks': ''}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
# 6 [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
# {'swim': 30.0, 'bike': 0.0, 'run': 0.0}
# {'start_date': datetime.date(2025, 6, 16), 'end_date': datetime.date(2025, 6, 23), 'strategy': 'peak', 'start_block': False, 'workouts': [[], [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}], [], [], [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}], [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]], 'fitness_outcome': {'run': 129.4374563277009, 'bike': 134.49024185306786, 'swim': 136.3099874889589}, 'fatigue_outcome': {'swim': 30.0, 'bike': 0.0, 'run': 0.0}}
# 0 []
# 1 [{'sport': 'swim', 'workout_name': 'tempo intervals', 'intensity': 6.0, 'duration': 30.0, 'fatigue_increase': 20.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 2 [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
# 3 []
# 4 []
# 5 [{'sport': 'swim', 'workout_name': 'open water current intervals', 'intensity': 8.0, 'duration': 20.0, 'fatigue_increase': 30.0, 'fitness_increase': 3.0, 'week_blocks': ''}]
# 6 [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
# {'swim': 0.0, 'bike': 65.0, 'run': 50.0}
# {'start_date': datetime.date(2025, 6, 23), 'end_date': datetime.date(2025, 6, 30), 'strategy': 'peak', 'start_block': False, 'workouts': [[{'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}], [], [], [], [], [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'crisscross intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 4.5, 'week_blocks': 'base'}], [{'sport': 'swim', 'workout_name': 'anaerobic capacity intervals', 'intensity': 10.0, 'duration': 20.0, 'fatigue_increase': 75.0, 'fitness_increase': 4.5, 'week_blocks': 'base'}, {'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]], 'fitness_outcome': {'run': 133.46558351131586, 'bike': 139.76572976041444, 'swim': 133.99448811451097}, 'fatigue_outcome': {'swim': 0.0, 'bike': 65.0, 'run': 50.0}}
# 0 [{'sport': 'run', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 40.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
# 1 []
# 2 []
# 3 []
# 4 []
# 5 [{'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}, {'sport': 'run', 'workout_name': 'crisscross intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 50.0, 'fitness_increase': 4.5, 'week_blocks': 'base'}]
# 6 [{'sport': 'swim', 'workout_name': 'anaerobic capacity intervals', 'intensity': 10.0, 'duration': 20.0, 'fatigue_increase': 75.0, 'fitness_increase': 4.5, 'week_blocks': 'base'}, {'sport': 'bike', 'workout_name': 'hill intervals', 'intensity': 9.0, 'duration': 30.0, 'fatigue_increase': 65.0, 'fitness_increase': 6.0, 'week_blocks': 'base'}]
